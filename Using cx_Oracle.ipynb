# %%
import cx_Oracle as db

connection = db.connect("<username>/<password>@vdec")
cursor = connection.cursor()
cursor.execute("select * from static_ref.instrument")
instruments = cursor.fetchall()
print(instruments)
cursor.close()
connection.close()
# Out:
# [(1117265, 'HMP45C Temperature and Humidity Sensor', 'HMP45C', '-', 'd', 20.0, 2.4999999999999998e-05, 1.0, '/ops/software/shi/config/station_specs/rsp', '-', '-', datetime.datetime(2009, 7, 30, 12, 30, 2)), (1117268, 'DASE absolute microbarometer', 'MB2000', 's', 'd', 20.0, 0.0001, 10.0, '/ops/software/shi/config/station_specs/rsp', 'I43RU_BDF_rsp_20090420', 'pazfap', datetime.datetime(2009, 7, 30, 12, 30, 2)), (1117267, 'GILL Wind Observer II Ultrasonic Wind Sensor', 'GILWO2', '-', 'd', 20.0, 1.2e-05, 1.0, '/ops/software/shi/config/station_specs/rsp', '-', '-', datetime.datetime(2009, 7, 30, 12, 30, 2)), (1117275, 'DASE absolute microbarometer', 'MB2000', '-', 'd', 20.0, 0.02, 1.0, '/ops/software/shi/config/station_specs/rsp', '-', '-', datetime.datetime(2009, 7, 30, 12, 30, 2)), (1117266, 'GILL Wind Observer II Ultrasonic Wind Sensor', 'GILWO2', '-', 'd', 20.0, 8.9e-05, 1.0, '/ops/software/shi/config/station_specs/rsp', '-', '-', datetime.datetime(2009, 7, 30, 12, 30, 2)), (111727
# ...
